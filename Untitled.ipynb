# %%
import pandas as pd

# %%
pd.read_excel("")
# Out:
#     Roll_No        Name   Python  Flask  Django  Javascript  Pandas  Numpy
# 0         1        ubaid      88     70      66          54      55     60
# 1         2          ali      44     50      77          34      78     80
# 2         3        imran      33     60      34          30      66     35
# 3         4        ahmed      45     80      55          40      77     36
# 4         5         hina      66     35      66          89      34     39
# 5         6        anaya      24     36      78          88      55     88
# 6         7       afshan      55     39      99          54      66     44
# 7         8        sonia      78     88      54          89      78     34
# 8         9        mohid      66     44      34          23      99     54
# 9        10        salma      77     56      54          68      54     34
# 10       11         aqsa      34     43      34          98      34     30
# ...
